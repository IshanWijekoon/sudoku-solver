# %%
class ClassName:
    pass

# %%
class Board:
    pass

# %%
class Board:
    pass
    
gameboard = Board()

# %%
class Board:
    def spam():
        pass
    
gameboard = Board()

# %%
class Board:
    def spam(self):
        print('Spam!')
    
gameboard = Board()
gameboard.spam()
# Out:
# Spam!

# %%
class Board:
    def __init__(self, board):
        pass

puzzle = [
  [0, 0, 2, 0, 0, 8, 0, 0, 0],
  [0, 0, 0, 0, 0, 3, 7, 6, 2],
  [4, 3, 0, 0, 0, 0, 8, 0, 0],
  [0, 5, 0, 0, 3, 0, 0, 9, 0],
  [0, 4, 0, 0, 0, 0, 0, 2, 6],
  [0, 0, 0, 4, 6, 7, 0, 0, 0],
  [0, 8, 6, 7, 0, 4, 0, 0, 0],
  [0, 0, 0, 5, 1, 9, 0, 0, 8],
  [1, 7, 0, 0, 0, 6, 0, 0, 5]
]

gameboard = Board(puzzle)
